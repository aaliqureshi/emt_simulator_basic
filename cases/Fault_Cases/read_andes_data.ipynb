# %%
import numpy as np

# Load the .npz file
data = np.load("ieee14_fault_barq_out.npz")

# %%
# List arrays stored inside
print(data.files)
# Out:
# ['data']

# %%
data.allow_pickle = True

# %%
data["delta"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 data["delta"]
#
# File ~/miniforge3/envs/andes/lib/python3.8/site-packages/numpy/lib/npyio.py:260, in NpzFile.__getitem__(self, key)
#     258         return self.zip.read(key)
#     259 else:
# --> 260     raise KeyError("%s is not a file in the archive" % key)
#
# KeyError: 'delta is not a file in the archive'

# %%
print(data.files)
# Out:
# ['data']

# %%
data["data"][-1,81:85]
# Out:
# array([0.4 , 0.4 , 0.3 , 0.35])
