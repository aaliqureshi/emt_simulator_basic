# %%
import andes
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
# !andes prep
# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/SMIB_Chow/SMIB_RL_Line.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/5bus/pjm5bus.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/npcc/npcc_NoZero.xlsx', default_config= True)

ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/ieee14/ieee14_gentrip0.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/ieee14/ieee14_fault0.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/ieee14/ieee14_solar.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/ieee39/ieee39_full_OG.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/ieee14/ieee14_full.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/wecc/wecc_gencls.xlsx', default_config= True)

# ss1 = andes.load('/Users/aali27/Work/repos/andes/andes/cases/wecc/wecc_gencls_gentrip.xlsx', default_config= True)




ss1.PFlow.run()

# ss1.EIG.run()

ss1.TDS.config.honest = 1

ss1.config.save_stats = 1

ss1.TDS.config.tf = 10

ss1.TDS.config.criteria = 0

# ss1.TDS.config.tstep = 50e-3

ss1.TDS.run()
# Out:
# <ESST3Aqq> is not an existing model.
# <ESST3Aqq> is not an existing model.
# <ESST3Aqq> is not an existing model.
# <ESST3Aqq> is not an existing model.
#   0%|          | 0/100 [00:00<?, ?%/s]
# <Toggle Toggler_1>: GENROU.GENROU_2 status changed to 0 at t=0.5 sec.
# LTE = 4.08763 at t=0.50110s
# True

# %%
print(f"Accepted: {ss1.TDS.n_accepted} \t Rejected: {ss1.TDS.n_rejected}")
# Out:
# Accepted: 346 	 Rejected: 1

# %%
iters_trap = [x[1] for x in ss1.TDS.call_stats]
print("Trapezoid Iters: ", np.sum(iters_trap))
# Out:
# Trapezoid Iters:  746

# %%
lte1 = ss1.TDS.err

# %%
ss1.TDS.plt.plot(ss1.GENROU.omega)
# Out:
# (<Figure size 640x480 with 1 Axes>, <Axes: xlabel='Time [s]'>)

# %%
plt.plot(np.diff(ss1.dae.ts.t)[1:])

# %%
dt = np.diff(ss1.dae.ts.t)

# %%
avg = np.mean(dt)

std = np.std(dt)

# %%
print(f'Avg: {avg} \t Std.: {std}')
# Out:
# Avg: 0.028985507246376812 	 Std.: 0.004696894424594855
